# %%
import openai
openai.api_key_path = 'key_openai.txt'

# %%
openai.FineTune.list()
# Out:
# <OpenAIObject list at 0x1277da450> JSON: {
#   "data": [
#     {
#       "created_at": 1676884722,
#       "fine_tuned_model": null,
#       "hyperparams": {
#         "batch_size": 8,
#         "learning_rate_multiplier": 0.1,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.01
#       },
#       "id": "ft-QikmwwDwDaVyHvwcxmfNoa1z",
#       "model": "davinci",
#       "object": "fine-tune",
#       "organization_id": "org-c6u2GK4EOdxh4JnxrtOq2cL0",
#       "result_files": [],
#       "status": "cancelled",
#       "training_files": [
#         {
#           "bytes": 455801,
#           "created_at": 1676884722,
#           "filename": "./data/processed/messages_prepared (1).jsonl",
#           "id": "file-lXZYIj2Xu6xEp3SI7UllsKCi",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1676885182,
#       "validation_files": []
#     },
#     {
# ...

# %%
ft = openai.FineTune

ft.retrieve(id='ft-QikmwwDwDaVyHvwcxmfNoa1z')
# Out:
# <FineTune fine-tune id=ft-QikmwwDwDaVyHvwcxmfNoa1z at 0x127520b30> JSON: {
#   "created_at": 1676884722,
#   "events": [
#     {
#       "created_at": 1676884722,
#       "level": "info",
#       "message": "Created fine-tune: ft-QikmwwDwDaVyHvwcxmfNoa1z",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1676885045,
#       "level": "info",
#       "message": "Fine-tune costs $10.20",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1676885046,
#       "level": "info",
#       "message": "Fine-tune enqueued. Queue number: 19",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1676885135,
#       "level": "info",
#       "message": "Fine-tune is in the queue. Queue number: 18",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1676885182,
#       "level": "info",
#       "message": "Fine-tune cancelled",
#       "object": "fine-tune-event"
#     }
#   ],
#   "fine_tuned_model": null,
# ...
